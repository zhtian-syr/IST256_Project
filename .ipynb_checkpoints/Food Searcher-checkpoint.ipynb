# %%
import requests
import json
#url="https://maps.googleapis.com/maps/api/staticmap?center=Brooklyn+Bridge,New+York,NY&zoom=13&size=600x300&maptype=roadmap&markers=color:blue%7Clabel:S%7C40.702147,-74.015794&markers=color:green%7Clabel:G%7C40.711614,-74.012318&markers=color:red%7Clabel:C%7C40.718217,-73.998284&"
#resp=requests.get(url)
#resp.text
key="gxy7IYotnmfdd1SrvXfy1hfG5z4HfU0pGbbVPclKWAy07uqNviLGHrnzp0J_Nt1hJ_vQd4AnIX3LQzh1SV9vybXQpR_MpvhhZTIUrx8b6K0Qp4yfU0wrPDQE_wDXXXYx"
#def yelp(food):
user_id="lUrLPc8-KXBjLODVZRvkRQ"
url='https://api.yelp.com/v3/autocomplete?text=del&latitude=37.786882&longitude=-122.399972'
#print(url)
data={'Authorization': 'lUrLPc8-KXBjLODVZRvkRQ'}
response = requests.get(url,params="data")
#return(response.json())
#user_text=input("")
#food = { 'term' : user_text,'latitude': 43.03821555,'longitude': -76.1333456417294,'radius': 40000}
#yelp(food)
response.json()
# Out:
# {'error': {'code': 'VALIDATION_ERROR',
#   'description': 'Authorization is a required parameter.',
#   'field': 'Authorization',
#   'instance': None}}

# %%
from urllib.parse import quote
import json
import pandas as pd
import requests
import folium

API_KEY= 'gxy7IYotnmfdd1SrvXfy1hfG5z4HfU0pGbbVPclKWAy07uqNviLGHrnzp0J_Nt1hJ_vQd4AnIX3LQzh1SV9vybXQpR_MpvhhZTIUrx8b6K0Qp4yfU0wrPDQE_wDXXXYx'

API_HOST = 'https://api.yelp.com'
SEARCH_PATH = '/v3/businesses/search'
BUSINESS_PATH = '/v3/businesses/'  
SEARCH_LIMIT = 10

def request(host, path, api_key, url_params=None):
    url_params = url_params or {}
    url = '{0}{1}'.format(host, quote(path.encode('utf8')))
    headers = {
        'Authorization': 'Bearer %s' % api_key,
    }

    print(u'Querying {0} ...'.format(url))

    response = requests.request('GET', url, headers=headers, params=url_params)

    return response.json()


def search(api_key, term, location):

    url_params = {
        'term': term.replace(' ', '+'),
        'location': location.replace(' ', '+'),
        'limit': SEARCH_LIMIT
    }
    return request(API_HOST, SEARCH_PATH, api_key, url_params=url_params)

get_type=input("Enter the type of the restaurant(Asian,French,Japanese...etc.): ")
get_location=input("Enter a location: ")
restaurants=search(API_KEY,get_type,get_location)


name=[]
address=[]
rating=[]
location=[]
for num in restaurants['businesses']:
    name.append(num['name'])
    address.append(num['location']['address1'])
    rating.append(num['rating'])
    location.append((num['coordinates']['latitude'],num['coordinates']['longitude']))
series_dict = { 'Name':  name,'Address': address,'Rating on Yelp': rating}  
show_table=pd.DataFrame(series_dict)
display(show_table)
restaurants
# Out:
# Enter the type of the restaurant(Asian,French,Japanese...etc.): Japanese
# Enter a location: new york
# Querying https://api.yelp.com/v3/businesses/search ...
#                 Name              Address  Rating on Yelp
# 0     Kaikagetsu NYC       162 Orchard St             4.5
# 1            Benemon         108 E 4th St             4.5
# 2        Aoi Kitchen         320 E 6th St             4.5
# 3     Ootoya Chelsea          8 W 18th St             4.0
# 4       Izakaya Fuku  71-28 Roosevelt Ave             4.5
# 5          Nami Nori        33 Carmine St             4.0
# 6  DOMODOMO New York     140 W Houston St             4.5
# 7            Okonomi       150 Ainslie St             4.5
# 8               Raku         342 E 6th St             4.5
# 9             nonono      118 Madison Ave             4.5
# {'businesses': [{'id': 'ax4INkzwL__-d_kGJfcA-w',
#    'alias': 'kaikagetsu-nyc-new-york-2',
#    'name': 'Kaikagetsu NYC',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/m_ARAOwDgHTjn3WkmwkolA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaikagetsu-nyc-new-york-2?adjust_creative=lUrLPc8-KXBjLODVZRvkRQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lUrLPc8-KXBjLODVZRvkRQ',
#    'review_count': 52,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72104, 'longitude': -73.98848},
#    'transactions': ['restaurant_reservation'],
#    'location': {'address1': '162 Orchard St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 Orchard St', 'New York, NY 10002']},
#    'phone': '+16465903900',
#    'display_phone': '(646) 590-3900',
#    'distance': 1800.6650070425846},
#   {'id': 'axqp3pGJXnTLgq2QrPyDyQ',
#    'alias': 'benemon-new-york',
#    'name': 'Benemon',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/B-_lF8sP0pLsAiuvxZFjLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/benemon-new-york?adjust_creative=lUrLPc8-KXBjLODVZRvkRQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lUrLPc8-KXBjLODVZRvkRQ',
#    'review_count': 529,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72551, 'longitude': -73.98838},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '108 E 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['108 E 4th St', 'New York, NY 10003']},
#    'phone': '+12126143006',
#    'display_phone': '(212) 614-3006',
#    'distance': 2289.2038585586733},
#   {'id': 'lEH8EUPX3Zn_trHauIycYw',
#    'alias': 'aoi-kitchen-new-york',
#    'name': 'Aoi Kitchen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tPGMcy5hTbT-3qJgDYb3BA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aoi-kitchen-new-york?adjust_creative=lUrLPc8-KXBjLODVZRvkRQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lUrLPc8-KXBjLODVZRvkRQ',
#    'review_count': 30,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72683167, 'longitude': -73.98754333},
#    'transactions': ['pickup'],
#    'location': {'address1': '320 E 6th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['320 E 6th St', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2442.622359813582},
#   {'id': 'OLSSJIp8pu5UlugTF7tuHA',
#    'alias': 'ootoya-chelsea-new-york',
#    'name': 'Ootoya Chelsea',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/W8ZWQDEq3e9FjiRZwRNRNg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ootoya-chelsea-new-york?adjust_creative=lUrLPc8-KXBjLODVZRvkRQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lUrLPc8-KXBjLODVZRvkRQ',
#    'review_count': 1377,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.738767, 'longitude': -73.992778},
#    'transactions': ['restaurant_reservation', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '8 W 18th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8 W 18th St', 'New York, NY 10011']},
#    'phone': '+12122550018',
#    'display_phone': '(212) 255-0018',
#    'distance': 3707.4479106406193},
#   {'id': 'AudBWxeAr3zHr1ITrTcVpg',
#    'alias': 'izakaya-fuku-jackson-heights',
#    'name': 'Izakaya Fuku',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XI6NDBHV3wqZYixxb4tH5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/izakaya-fuku-jackson-heights?adjust_creative=lUrLPc8-KXBjLODVZRvkRQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lUrLPc8-KXBjLODVZRvkRQ',
#    'review_count': 27,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74635, 'longitude': -73.89383},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '71-28 Roosevelt Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['71-28 Roosevelt Ave', 'Jackson Heights, NY 11372']},
#    'phone': '+17182551120',
#    'display_phone': '(718) 255-1120',
#    'distance': 9608.700043409099},
#   {'id': 'lY_gb_hNbit6GHBiOn3VeQ',
#    'alias': 'nami-nori-new-york',
#    'name': 'Nami Nori',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/krcf7le7RKERieqyRtKoIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nami-nori-new-york?adjust_creative=lUrLPc8-KXBjLODVZRvkRQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lUrLPc8-KXBjLODVZRvkRQ',
#    'review_count': 62,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.730284, 'longitude': -74.003212},
#    'transactions': [],
#    'location': {'address1': '33 Carmine St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33 Carmine St', 'New York, NY 10014']},
#    'phone': '+16469984588',
#    'display_phone': '(646) 998-4588',
#    'distance': 2864.063123533261},
#   {'id': 'BPZfuPvSxCfoppU4lPFm0Q',
#    'alias': 'domodomo-new-york-new-york-2',
#    'name': 'DOMODOMO New York',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6pJRtg2Mm7lpYWMu4dsflg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/domodomo-new-york-new-york-2?adjust_creative=lUrLPc8-KXBjLODVZRvkRQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lUrLPc8-KXBjLODVZRvkRQ',
#    'review_count': 1025,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72803, 'longitude': -74.00167},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$$',
#    'location': {'address1': '140 W Houston St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['140 W Houston St', 'New York, NY 10012']},
#    'phone': '+16467070301',
#    'display_phone': '(646) 707-0301',
#    'distance': 2591.0031789344716},
#   {'id': '7OMGEtFWT6sdd9TVuoGqJQ',
#    'alias': 'okonomi-brooklyn',
#    'name': 'Okonomi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Dw8nY5l1VF6U0xkCkWQxIw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/okonomi-brooklyn?adjust_creative=lUrLPc8-KXBjLODVZRvkRQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lUrLPc8-KXBjLODVZRvkRQ',
#    'review_count': 448,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.712622, 'longitude': -73.9487843},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '150 Ainslie St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 Ainslie St', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3918.0469578683437},
#   {'id': 'FlZ1zdVEKWv7dwqm8Uw8-w',
#    'alias': 'raku-new-york-7',
#    'name': 'Raku',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GEbZnH1jR4n7D5WOJ3urPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raku-new-york-7?adjust_creative=lUrLPc8-KXBjLODVZRvkRQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lUrLPc8-KXBjLODVZRvkRQ',
#    'review_count': 1014,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7264988089246,
#     'longitude': -73.9866526052356},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '342 E 6th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['342 E 6th St', 'New York, NY 10003']},
#    'phone': '+12122281324',
#    'display_phone': '(212) 228-1324',
#    'distance': 2428.0392489129867},
#   {'id': 'qm1J_dPA5IHij1oAnoZwHw',
#    'alias': 'nonono-new-york-6',
#    'name': 'nonono',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yhZYzx5cnn8SFFF8eZdRHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nonono-new-york-6?adjust_creative=lUrLPc8-KXBjLODVZRvkRQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=lUrLPc8-KXBjLODVZRvkRQ',
#    'review_count': 624,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'izakaya', 'title': 'Izakaya'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74545, 'longitude': -73.98499},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '118 Madison Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['118 Madison Ave', 'New York, NY 10016']},
#    'phone': '+16467073227',
#    'display_phone': '(646) 707-3227',
#    'distance': 4515.897681612123}],
#  'total': 2700,
#  'region': {'center': {'longitude': -73.99429321289062,
#    'latitude': 40.70544486444615}}}

# %%
#businesses:{name:xx,location:{address1:xx,address2:xx},rating:xx,city:xx,}

# %%
def get_coordinates(search):
    url = 'https://nominatim.openstreetmap.org/search' 
    options = { 'q' : search, 'format' : 'json'}
    response = requests.get(url, params = options)            
    geodata = response.json()
    coords = { 'lat' : float(geodata[0]['lat']), 'lng' : float(geodata[0]['lon']) }
    return coords['lat'],coords['lng']

coords = get_coordinates(get_location)
show_map = folium.Map(location=coords, zoom_start=13)
d={'a':name,'b':rating,'c':address,'d':location}
for a in range(SEARCH_LIMIT):
    loc=(d['d'][a])
    message=f"Restaurant name:{d['a'][a]} Rating:{d['b'][a]} Address:{d['c'][a]}"
    marker = folium.Marker(location=loc,popup=message)
    show_map.add_child(marker)
    
    
show_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
